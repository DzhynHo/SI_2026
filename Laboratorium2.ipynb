# %% [markdown]
# <a href="https://colab.research.google.com/github/DzhynHo/SI_2026/blob/main/Laboratorium2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(tf.__version__)
# Out:
# 2.19.0

# %%
training_data = np.load('TF_dataset.npz')
input_size = 2
output_size = 1

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(5, activation="sigmoid"), # Warstwa ukryta 1 (5 neuronów)
    tf.keras.layers.Dense(5, activation="sigmoid"), # Warstwa ukryta 2 (5 neuronów)
    tf.keras.layers.Dense(output_size)              # Warstwa wyjściowa
])
model.compile(optimizer='adam', loss='mean_absolute_error')
model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 71.9204
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 71.2227
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 70.1008
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 68.8804
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 67.7374
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.6885
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 65.7137
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 64.8023
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 63.9561
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 63.1710
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 62.4373
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 61.7354
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 61.0539
# Epoch 14/100
# ...

# %%
model.layers[0].get_weights()
# Out:
# [array([[-0.5840395 , -0.42851403, -0.4421352 ,  0.4798109 , -0.84663   ],
#         [-0.30496573, -0.22418053, -0.24647251,  0.26349294, -0.46014515]],
#        dtype=float32),
#  array([ 0.2107803 , -1.9709189 , -0.83624345,  2.8303673 ,  3.1530483 ],
#        dtype=float32)]

# %%
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])),
         np.squeeze(training_data['targets']), color='orange')
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
